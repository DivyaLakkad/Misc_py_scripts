# %%
import pandas as pd
df_reg = pd.read_excel(r"C:\Users\divyal\Desktop\projects\NOVA Equip Py\Final Scripts Oct 1\reg_mar_sept_test.xlsx", engine="openpyxl", usecols="A,D,H")
df_reg
# Out:
#          EQUNR     BELDAT  WORKING_HR
# 0     20000236 2021-03-10        10.0
# 1     10005176 2021-03-10        10.0
# 2     10022077 2021-03-10        10.0
# 3     20000470 2021-03-10        10.0
# 4     20000478 2021-03-10        10.0
# ...        ...        ...         ...
# 1676  10022086 2021-09-30        10.0
# 1677  10003980 2021-09-30        10.0
# 1678  10005176 2021-09-30        10.0
# 1679  10003980 2021-10-01        10.0
# 1680  10003980 2021-10-02        10.0
#
# [1681 rows x 3 columns]

# %%
def unique(list1):
    # intilize a null list
    unique_list = []

    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)

    return unique_list

# %%
eqp_list = df_reg["EQUNR"].to_list()
eqp_unique_list = unique(eqp_list)
eqp_unique_list
# Out:
# [20000236,
#  10005176,
#  10022077,
#  20000470,
#  20000478,
#  20000484,
#  20000489,
#  20000534,
#  20000541,
#  20002196,
#  10022041,
#  20002167,
#  10022086,
#  10022087,
#  10020391,
#  10005187,
#  10003980,
#  20000495,
#  10020471,
#  10022088,
#  10022078,
#  10022049]

# %%
def weekly_total(row):

# %%
grouped = df_reg.groupby(df_reg["EQUNR"])
for i in eqp_unique_list:
    df_each = pd.DataFrame(grouped.get_group(i))
    df_billable['Employee/Unit'] = df_each.apply(lambda row: emp_unit(row), axis=1)
# Out:
#          EQUNR     BELDAT  WORKING_HR
# 0     20000236 2021-03-10        10.0
# 12    20000236 2021-03-11        10.0
# 25    20000236 2021-03-12        11.5
# 31    20000236 2021-03-13        11.5
# 37    20000236 2021-03-14        11.0
# ...        ...        ...         ...
# 1588  20000236 2021-09-23         9.0
# 1589  20000236 2021-09-23         1.0
# 1611  20000236 2021-09-27         5.0
# 1612  20000236 2021-09-27         5.0
# 1659  20000236 2021-09-30        10.0
#
# [128 rows x 3 columns]
#          EQUNR     BELDAT  WORKING_HR
# 1     10005176 2021-03-10        10.0
# 13    10005176 2021-03-11        10.0
# 22    10005176 2021-03-12        11.5
# 28    10005176 2021-03-13        11.5
# 34    10005176 2021-03-14        11.5
# 48    10005176 2021-03-15        10.0
# 50    10005176 2021-03-15        11.5
# 61    10005176 2021-03-16        11.5
# 71    10005176 2021-03-17        10.0
# 72    10005176 2021-03-17        11.5
# 99    10005176 2021-03-22        10.0
# ...
